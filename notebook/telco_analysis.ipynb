# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Business Context
# You are working for a wealthy investor that specialises in purchasing assets that are undervalued.  This investor’s due diligence on all purchases includes a detailed analysis of the data that underlies the business, to try to understand the fundamentals of the business and especially to identify opportunities to drive profitability by changing the focus of which products or services are being offered.
#
# Your last role with this investor saw you do a rich analysis of a delivery company and you helped to identify that delivery to university students was the most profitable route to follow, and your analysis helped the investor purchase this delivery company and ramp up profits by 25% within 6 months through focussing on the most profitable aspect of the business.  This was driven by university students always being hungry, awake at all hours, willing to purchase from a limited food menu and tending to live within a small geographical area.
#
# The investor is interested in purchasing TellCo, an existing mobile service provider in the Republic of Pefkakia.  TellCo’s current owners have been willing to share their financial information but have never employed anyone to look at their data that is generated automatically by their systems.
#
#
# ### Objective
# Your employer wants you to provide a report to analyse opportunities for growth and make a recommendation on whether TellCo is worth buying or selling.  You will do this by analysing a telecommunication dataset that contains useful information about the customers & their activities on the network. You will deliver insights you managed to extract to your employer through an easy to use web based dashboard and a written report.
#
#
#
# ### Data Description
# •	bearer id: xDr session identifier
#
# •	Dur. (ms): Total Duration of the xDR (in ms)
#
# •	Start Start time of the xDR (first frame timestamp)
#
# •	Start ms  Milliseconds offset of start time for the xDR (first frame timestamp)
#
# •	End   End time of the xDR (last frame timestamp)
#
# •	End ms    Milliseconds offset of end time of the xDR (last frame timestamp)
#
# •	Dur. (s)  Total Duration of the xDR (in s)
#
# •	IMSI  International Mobile Subscriber Identity
#
# •	MSISDN/Number MS International PSTN/ISDN Number of mobile - customer number
#
# •	IMEI  International Mobile Equipment Identity
#
# •	Last Location Name    User location call name (2G/3G/4G) at the end of the bearer
#
# •	Avg RTT DL (ms)   Average Round Trip Time measurement Downlink direction (msecond)
#
# •	Avg RTT UL (ms)   Average Round Trip Time measurement Uplink direction (msecond)
#
# •	Avg Bearer TP DL (kbps)   Average Bearer Throughput for Downlink (kbps) - based on BDR duration
#
# •	Avg Bearer TP UL (kbps) Average Bearer Throughput for uplink (kbps) - based on BDR duration
#
# •	TCP DL Retrans. Vol (Bytes) TCP volume of Downlink packets detected as retransmitted (bytes)
#
# •	TCP UL Retrans. Vol (Bytes) TCP volume of Uplink packets detected as retransmitted (bytes)
#
# •	DL TP < 50 Kbps (%) Duration ratio when Bearer Downlink Throughput < ….
#
# •	50 Kbps < DL TP < 250 Kbps (%)  Duration ratio when Bearer Downlink Throughput range is …
#
# •	250 Kbps < DL TP < 1 Mbps (%)   Duration ratio when Bearer Downlink Throughput range is …
#
# •	DL TP > 1 Mbps (%)  Duration ratio when Bearer Downlink Throughput > ….
#
# •	UL TP < 10 Kbps (%) Duration ratio when Bearer Uplink Throughput < ….
#
# •	10 Kbps < UL TP < 50 Kbps (%)   Duration ratio when Bearer Uplink Throughput range is …
#
# •	50 Kbps < UL TP < 300 Kbps (%)  Duration ratio when Bearer Uplink Throughput range is …
#
# •	UL TP > 300 Kbps (%)    Duration ratio when Bearer Uplink Throughput > ….
#
# •	HTTP DL (Bytes) HTTP data volume (in Bytes) received by the MS during this session
#
# •	HTTP UL (Bytes) HTTP data volume (in Bytes) sent by the MS during this session
#
# •	Activity Duration DL (ms)   Activity Duration for downlink (ms) - excluding periods of inactivity > 500 ms
#
# •	Activity Duration UL (ms)   Activity Duration for uplink (ms) - excluding periods of inactivity > 500 ms
#
# •	Dur. (ms).1 Total Duration of the xDR (in ms)
#
# •	Handset Manufacturer    Handset manufacturer
#
# •	Handset Type    Handset type of the mobile device
#
# •	Nb of sec with 125000B < Vol DL Number of seconds with IP Volume DL >
#
# •	Nb of sec with 1250B < Vol UL < 6250B   Number of seconds with IP Volume UL between …
#
# •	Nb of sec with 31250B < Vol DL < 125000B    Number of seconds with IP Volume DL between …
#
# •	Nb of sec with 37500B < Vol UL  Number of seconds with IP Volume UL >
#
# •	Nb of sec with 6250B < Vol DL < 31250B  Number of seconds with IP Volume DL between …
#
# •	Nb of sec with 6250B < Vol UL < 37500B  Number of seconds with IP Volume UL between …
#
# •	Nb of sec with Vol DL < 6250B   Number of seconds with IP Volume DL <
#
# •	Nb of sec with Vol UL < 1250B   Number of seconds with IP Volume UL <
#
# •	Social Media DL (Bytes) Social Media data volume (in Bytes) received by the MS during this session
#
# •	Social Media UL (Bytes) Social Media data volume (in Bytes) sent by the MS during this session
#
# •	YouTube DL (Bytes)  YouTube data volume (in Bytes) received by the MS during this session
#
# •	YouTube UL (Bytes)  YouTube data volume (in Bytes) sent by the MS during this session
#
# •	Netflix DL (Bytes)  Netflix data volume (in Bytes) received by the MS during this session
#
# •	Netflix UL (Bytes)  Netflix data volume (in Bytes) sent by the MS during this session
#
# •	Google DL (Bytes)   Google data volume (in Bytes) Received by the MS during this session
#
# •	Google UL (Bytes)   Google data volume (in Bytes) sent by the MS during this session
#
# •	Email DL (Bytes)    Email data volume (in Bytes) Received by the MS during this session
#
# •	Email UL (Bytes)    Email data volume (in Bytes) sent by the MS during this session
#
# •	Gaming DL (Bytes)   Gaming data volume (in Bytes) Received by the MS during this session
#
# •	Gaming UL (Bytes)   Gaming data volume (in Bytes) sent by the MS during this session
#
# •	Other DL    Other data volume (in Bytes) received by the MS during this session
#
# •	Other UL    Other data volume (in Bytes) sent by the MS during this session
#
# •	Total DL (Bytes)    Data volume (in Bytes) received by the MS during this session (IP layer + overhead)
#
# •	Total UL (Bytes)    Data volume (in Bytes) sent by the MS during this session (IP layer + overhead)

# %% [markdown]
# ## Importing necessary libraries

# %%
# data manipulation
import pandas as pd
import numpy as np

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# sql
from sqlalchemy import create_engine

# hide warnings
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# ## Loading the dataset

# %%
# Replace 'telecom' with your database name, 'postgres' with your username, and 'your_password' with your password
# Replace 'localhost' with your database host if different
engine = create_engine('postgresql://postgres:psgres@localhost/telecom')

# SQL query to execute
query = "SELECT * FROM xdr_data;"  # Replace 'xdr_data' with your table name

# Reading data into a DataFrame
df = pd.read_sql(query, engine)

# %% [markdown]
# ## Data Overview

# %%
# first five rows of our traffic dataset
df.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %%
# shape of our data
print('There are', df.shape[0], 'rows and', df.shape[1], 'columns in our df', '\n')
# Out:
# There are 150001 rows and 55 columns in our df

# %%
# checking data types of our columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %% [markdown]
# - Start, End, Last location name, handset man, handset type are categorical columns
# - The rest of the columns are of numerical data type.
# - Some columns do not have appropriate data types; this will be dealt with later

# %%
# statistical summary
df.describe().T
# Out:
#                                              count          mean  \
# Bearer Id                                 149010.0  1.013887e+19
# Start ms                                  150000.0  4.991882e+02
# End ms                                    150000.0  4.988009e+02
# Dur. (ms)                                 150000.0  1.046086e+05
# IMSI                                      149431.0  2.082016e+14
# MSISDN/Number                             148935.0  4.188282e+10
# IMEI                                      149429.0  4.847455e+13
# Avg RTT DL (ms)                           122172.0  1.097957e+02
# Avg RTT UL (ms)                           122189.0  1.766288e+01
# Avg Bearer TP DL (kbps)                   150000.0  1.330005e+04
# Avg Bearer TP UL (kbps)                   150000.0  1.770429e+03
# TCP DL Retrans. Vol (Bytes)                61855.0  2.080991e+07
# TCP UL Retrans. Vol (Bytes)                53352.0  7.596587e+05
# ...

# %% [markdown]
# - Most calls last for a period of 1.04ms
# - Most users have a total ul of about 4.11 bytes
# - Most users have a total dl of about 4.55 bytes

# %%
# unique values of our categorical columns
# Helps with identifying missing values that have posed as ?
categorical_col=df.select_dtypes(include='object')
for col in categorical_col:
    print(f"Unique values in {col}:")
    print(df[col].unique())
    print("\n")
# Out:
# Unique values in Start:
# ['4/4/2019 12:01' '4/9/2019 13:04' '4/9/2019 17:42' ... '4/29/2019 7:27'
#  '4/29/2019 7:28' None]
#
#
# Unique values in End:
# ['4/25/2019 14:35' '4/25/2019 8:15' '4/25/2019 11:58' ...
#  '4/30/2019 23:18' '4/30/2019 22:32' None]
#
#
# Unique values in Last Location Name:
# ['9.16456699548519E+015' 'L77566A' 'D42335A' ... 'D20434A' 'T51102A'
#  'L88342B']
#
#
# Unique values in Handset Manufacturer:
# ['Samsung' 'undefined' 'Huawei' 'Apple' 'Zte'
#  'TP-Link Technologies Co Ltd' 'Ertebat Hamrah Guya Arvand'
#  'Wiko Global Sasu' None 'TCL Communication Ltd'
#  'Oneplus Technology (Shenzhen) Co Ltd' 'Zebra Technologies Corp.' 'Nokia'
#  'Wiko' 'Tcl Communication Ltd' 'ZTE' 'Lenovo' 'Asustek'
#  'Xiaomi Communications Co Ltd' 'Rim' 'Hmd Global Oy'
#  'Sony Mobile Communications AB' 'D-Link Corporation' 'Wct'
#  'Dn Electronics' 'Sony Mobile Communications Ab' 'Netgear Inc'
#  'Neel Enterprise' 'Teletalk Pvt Ltd' 'DDM Brands LLC'
# ...

# %%
# unique values of our numerical columns
# Helps with identifying missing values that have posed as ?
numerical_cols=df.select_dtypes(include='float64')
for col in numerical_cols:
    print(f"Unique values in {col}:")
    print(df[col].unique())
    print("\n")
# Out:
# Unique values in Bearer Id:
# [1.31144835e+19 1.31144835e+19 1.31144835e+19 ... 7.27782567e+18
#  7.34988326e+18 1.31144836e+19]
#
#
# Unique values in Start ms:
# [770. 235.   1. ... 431.  95.  nan]
#
#
# Unique values in End ms:
# [662. 606. 652. ...  91. 499.  nan]
#
#
# Unique values in Dur. (ms):
# [1823652. 1365104. 1361762. ...   81230.   98249.      nan]
#
#
# Unique values in IMSI:
# [2.08201448e+14 2.08201909e+14 2.08200314e+14 ... 2.08202201e+14
#  2.08201711e+14 2.08202101e+14]
#
#
# Unique values in MSISDN/Number:
# [3.36649622e+10 3.36818544e+10 3.37606271e+10 ... 3.36506887e+10
#  3.36218901e+10 3.36196221e+10]
#
#
# Unique values in IMEI:
# [3.55212095e+13 3.57940090e+13 3.52815104e+13 ... 3.54831095e+13
#  3.57212099e+13 8.61862040e+13]
#
#
# Unique values in Avg RTT DL (ms):
# [   42.    65.    nan ...  1433. 13431.  4274.]
#
#
# Unique values in Avg RTT UL (ms):
# [5.000e+00       nan 1.800e+01 7.000e+00 4.000e+00 3.300e+01 2.000e+00
# ...

# %% [markdown]
# - We can observe that some numerical columns have `nan` values

# %% [markdown]
# ## Data Preprocessing
#
# - Missing value treatment (if needed)
# - Feature engineering
# - Outlier detection and treatment (if needed)
# - Preparing data for modeling
# - Any other preprocessing steps (if needed)

# %%
# Converting date/time columns to datetime type
df['Start'] = pd.to_datetime(df['Start'])
df['End'] = pd.to_datetime(df['End'])

# Converting identifier columns to object (string) type
df['Bearer Id'] = df['Bearer Id'].astype('object')
df['IMSI'] = df['IMSI'].astype('object')
df['MSISDN/Number'] = df['MSISDN/Number'].astype('object')
df['IMEI'] = df['IMEI'].astype('object')

# Displaying the updated data types to confirm changes
df.dtypes
# Out:
# Bearer Id                                           object
# Start                                       datetime64[ns]
# Start ms                                           float64
# End                                         datetime64[ns]
# End ms                                             float64
# Dur. (ms)                                          float64
# IMSI                                                object
# MSISDN/Number                                       object
# IMEI                                                object
# Last Location Name                                  object
# Avg RTT DL (ms)                                    float64
# Avg RTT UL (ms)                                    float64
# Avg Bearer TP DL (kbps)                            float64
# Avg Bearer TP UL (kbps)                            float64
# TCP DL Retrans. Vol (Bytes)                        float64
# TCP UL Retrans. Vol (Bytes)                        float64
# ...

# %%
# check for duplicated values in our columns
# dupplicated() returns a boolean value.
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 149996    False
# 149997    False
# 149998    False
# 149999    False
# 150000    False
# Length: 150001, dtype: bool

# %%
# selecting the instances where missing value is greater than 0
pd.DataFrame({'Count':df.isnull().sum()[df.isnull().sum()>0],'Percentage':(df.isnull().sum()[df.isnull().sum()>0]/df.shape[0])*100})
# Out:
#                                            Count  Percentage
# Bearer Id                                    991    0.660662
# Start                                          1    0.000667
# Start ms                                       1    0.000667
# End                                            1    0.000667
# End ms                                         1    0.000667
# Dur. (ms)                                      1    0.000667
# IMSI                                         570    0.379997
# MSISDN/Number                               1066    0.710662
# IMEI                                         572    0.381331
# Last Location Name                          1153    0.768662
# Avg RTT DL (ms)                            27829   18.552543
# Avg RTT UL (ms)                            27812   18.541210
# Avg Bearer TP DL (kbps)                        1    0.000667
# Avg Bearer TP UL (kbps)                        1    0.000667
# ...

# %% [markdown]
# - Nb of sec with 125000B < Vol DL, Nb of sec with 1250B < Vol UL < 6250B, Nb of sec with 37500B < Vol UL, Nb of sec with 6250B < Vol DL < 31250B, Nb of sec with 6250B < Vol UL < 37500B have a `high` percentage of missing values.
# - I shall not drop these columns, I shall impute the missing values.
# - The rest of the columns have a `low` percentage of missing values.

# %%
# Impute missing values with the mean of each column
for col in numerical_cols:
    df[col].fillna(df[col].mean(), inplace=True)
    
    
numerical_cols
# Out:
#            Bearer Id  Start ms  End ms  Dur. (ms)          IMSI  \
# 0       1.311448e+19     770.0   662.0  1823652.0  2.082014e+14
# 1       1.311448e+19     235.0   606.0  1365104.0  2.082019e+14
# 2       1.311448e+19       1.0   652.0  1361762.0  2.082003e+14
# 3       1.311448e+19     486.0   171.0  1321509.0  2.082014e+14
# 4       1.311448e+19     565.0   954.0  1089009.0  2.082014e+14
# ...              ...       ...     ...        ...           ...
# 149996  7.277826e+18     451.0   214.0    81230.0  2.082022e+14
# 149997  7.349883e+18     483.0   187.0    97970.0  2.082019e+14
# 149998  1.311448e+19     283.0   810.0    98249.0  2.082017e+14
# 149999  1.311448e+19     696.0   327.0    97910.0  2.082021e+14
# 150000           NaN       NaN     NaN        NaN           NaN
#
#         MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# 0        3.366496e+10  3.552121e+13             42.0              5.0
# ...

# %%
# Convert specified columns back to object data type after imputation
categorical_col = ['Bearer Id', 'IMSI', 'MSISDN/Number', 'IMEI', 'Last Location Name', 'Handset Manufacturer', 'Handset Type']
for column in categorical_col:
    df[column] = df[column].astype('object')

# Display the updated data types to confirm changes
df.dtypes
# Out:
# Bearer Id                                           object
# Start                                       datetime64[ns]
# Start ms                                           float64
# End                                         datetime64[ns]
# End ms                                             float64
# Dur. (ms)                                          float64
# IMSI                                                object
# MSISDN/Number                                       object
# IMEI                                                object
# Last Location Name                                  object
# Avg RTT DL (ms)                                    float64
# Avg RTT UL (ms)                                    float64
# Avg Bearer TP DL (kbps)                            float64
# Avg Bearer TP UL (kbps)                            float64
# TCP DL Retrans. Vol (Bytes)                        float64
# TCP UL Retrans. Vol (Bytes)                        float64
# ...

# %%
# Select object columns only
#object_cols = df.select_dtypes(include=['object']).columns

# Impute missing values with the mode of each column
#for col in object_cols:
    #df[col].fillna(df[col].mode(), inplace=True)
    
    
    
for column in categorical_col:
    mode_value = df[column].mode()[0]
    df[column].fillna(mode_value, inplace=True)
    
    
categorical_col
# Out:
# ['Bearer Id',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Handset Manufacturer',
#  'Handset Type']

# %%
# Impute missing values in 'Start' and 'End' columns with the most frequent value (mode)
start_mode = df['Start'].mode()[0]
end_mode = df['End'].mode()[0]

df['Start'].fillna(start_mode, inplace=True)
df['End'].fillna(end_mode, inplace=True)

# %%
# selecting the instances where missing value is greater than 0
pd.DataFrame({'Count':df.isnull().sum()[df.isnull().sum()>0],'Percentage':(df.isnull().sum()[df.isnull().sum()>0]/df.shape[0])*100})
# Out:
# Empty DataFrame
# Columns: [Count, Percentage]
# Index: []

# %%
# Converting only float columns in the original DataFrame 'df' to integers
#for col in df.select_dtypes(include=['float64']).columns:
 #   df[col] = df[col].astype(int)

# %%
df.dtypes
# Out:
# Bearer Id                                           object
# Start                                       datetime64[ns]
# Start ms                                           float64
# End                                         datetime64[ns]
# End ms                                             float64
# Dur. (ms)                                          float64
# IMSI                                                object
# MSISDN/Number                                       object
# IMEI                                                object
# Last Location Name                                  object
# Avg RTT DL (ms)                                    float64
# Avg RTT UL (ms)                                    float64
# Avg Bearer TP DL (kbps)                            float64
# Avg Bearer TP UL (kbps)                            float64
# TCP DL Retrans. Vol (Bytes)                        float64
# TCP UL Retrans. Vol (Bytes)                        float64
# ...

# %%
numerical_cols = df.select_dtypes(include=['float64']).columns
numerical_cols
# Out:
# Index(['Start ms', 'End ms', 'Dur. (ms)', 'Avg RTT DL (ms)', 'Avg RTT UL (ms)',
#        'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'TCP DL Retrans. Vol (Bytes)', 'TCP UL Retrans. Vol (Bytes)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'HTTP DL (Bytes)', 'HTTP UL (Bytes)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)', 'Dur. (ms).1',
#        'Nb of sec with 125000B < Vol DL',
#        'Nb of sec with 1250B < Vol UL < 6250B',
#        'Nb of sec with 31250B < Vol DL < 125000B',
#        'Nb of sec with 37500B < Vol UL',
#        'Nb of sec with 6250B < Vol DL < 31250B',
#        'Nb of sec with 6250B < Vol UL < 37500B',
#        'Nb of sec with Vol DL < 6250B', 'Nb of sec with Vol UL < 1250B',
# ...

# %%
df.dtypes
# Out:
# Bearer Id                                           object
# Start                                       datetime64[ns]
# Start ms                                           float64
# End                                         datetime64[ns]
# End ms                                             float64
# Dur. (ms)                                          float64
# IMSI                                                object
# MSISDN/Number                                       object
# IMEI                                                object
# Last Location Name                                  object
# Avg RTT DL (ms)                                    float64
# Avg RTT UL (ms)                                    float64
# Avg Bearer TP DL (kbps)                            float64
# Avg Bearer TP UL (kbps)                            float64
# TCP DL Retrans. Vol (Bytes)                        float64
# TCP UL Retrans. Vol (Bytes)                        float64
# ...

# %%
# Setting the background color for visibility on the black screen
plt.figure(facecolor='white')

# Selecting numerical columns for outlier detection
#numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Creating subplots for numerical columns to check for outliers
fig, axes = plt.subplots(nrows=len(numerical_cols)//3 + 1, ncols=3, figsize=(18, 36))
axes = axes.flatten()  # Flatten the array of axes

for i, column in enumerate(numerical_cols):
    sns.boxplot(x=df[column], ax=axes[i])
    axes[i].set_title('Boxplot of ' + column)
    axes[i].set_xlabel('')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# to find the 25th percentile and 75th percentile for the numerical columns.
Q1 = df[numerical_cols].quantile(0.25)
Q3 = df[numerical_cols].quantile(0.75)
# Calculates the interquartile range (IQR) using the difference
# between the 75th and 25th percentiles
IQR = Q3 - Q1                   
# calculating lower whisker and upper whisker
lower_whisker = Q1 - 1.5*IQR    
upper_whisker = Q3 + 1.5*IQR

# %%
# Percentage of outliers in each column
((df[numerical_cols] < lower_whisker) | (df[numerical_cols] > upper_whisker)).sum()/df.shape[0]*100
# Out:
# Start ms                                     0.000000
# End ms                                       0.000000
# Dur. (ms)                                    4.789301
# Avg RTT DL (ms)                              5.145299
# Avg RTT UL (ms)                              5.983293
# Avg Bearer TP DL (kbps)                      8.823275
# Avg Bearer TP UL (kbps)                     14.353904
# TCP DL Retrans. Vol (Bytes)                  1.683322
# TCP UL Retrans. Vol (Bytes)                  0.879994
# DL TP < 50 Kbps (%)                         12.234585
# 50 Kbps < DL TP < 250 Kbps (%)              10.146599
# 250 Kbps < DL TP < 1 Mbps (%)               19.833868
# DL TP > 1 Mbps (%)                          15.230565
# UL TP < 10 Kbps (%)                         14.748568
# 10 Kbps < UL TP < 50 Kbps (%)               21.860521
# 50 Kbps < UL TP < 300 Kbps (%)               3.556643
# UL TP > 300 Kbps (%)                         2.165986
# ...

# %% [markdown]
# - Outliers in all columns are genuine values and are not unrealistic, therefore `we shall not treat them.`

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# creating function for histogram n boxplot
def histogram_boxplot(df, feature, figsize=(15, 10), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (15,10))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=df, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a triangle will indicate the mean value of the column
    sns.histplot(
        data=df, x=feature, kde=kde, ax=ax_hist2, bins=bins
    ) if bins else sns.histplot(
        data=df, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        df[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        df[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram
    
    

# function to create labeled barplots
def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 2, 6))
    else:
        plt.figure(figsize=(n + 2, 6))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n],
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# ### Univariate Analysis

# %%
histogram_boxplot(df, 'Dur. (ms)')

# %%
histogram_boxplot(df, 'Start ms')

# %%
histogram_boxplot(df, 'End ms')

# %%
histogram_boxplot(df, 'Social Media DL (Bytes)')

# %%
histogram_boxplot(df, 'Total DL (Bytes)')

# %% [markdown]
# - All downlink columns have a symmetrical distribution.
# - Dur ms has a symmetrical distribution.

# %%
labeled_barplot(df, 'Handset Manufacturer', perc=True, n=10 )

# %%
labeled_barplot(df, 'IMEI', perc=True, n=10 )

# %%
labeled_barplot(df, 'Handset Type', perc=True, n=10 )

# %% [markdown]
# - Top 3 handset manufacturers are: Apple, Samsung, Huawei
# - Most used handet is a Huawei B528S

# %% [markdown]
# ### Bivariate Analysis

# %%
# correlation map
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(numeric_only=True), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %% [markdown]
# #### Objectives

# %% [markdown]
# ##### Task 2

# %%
#1
# Identifying the top 10 handsets used by the customers
top_10_handsets = df['Handset Type'].value_counts().head(10)
print('Top 10 Handsets Used by Customers:')
print(top_10_handsets)
# Out:
# Top 10 Handsets Used by Customers:
# Handset Type
# Huawei B528S-23A                20324
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: count, dtype: int64

# %%
#2
# Identifying the top 3 handset manufacturers
top_3_manufacturers = df['Handset Manufacturer'].value_counts().head(3)
print('Top 3 Handset Manufacturers:')
print(top_3_manufacturers)
# Out:
# Top 3 Handset Manufacturers:
# Handset Manufacturer
# Apple      60137
# Samsung    40839
# Huawei     34423
# Name: count, dtype: int64

# %%
#3
# Identifying the top 5 handsets for each of the top 3 handset manufacturers

# Filtering data for each manufacturer and getting top 5 handsets
apple_top_5 = df[df['Handset Manufacturer'] == 'Apple']['Handset Type'].value_counts().head(5)
samsung_top_5 = df[df['Handset Manufacturer'] == 'Samsung']['Handset Type'].value_counts().head(5)
huawei_top_5 = df[df['Handset Manufacturer'] == 'Huawei']['Handset Type'].value_counts().head(5)

print('Top 5 Handsets for Apple:')
print(apple_top_5)
print('\
Top 5 Handsets for Samsung:')
print(samsung_top_5)
print('\
Top 5 Handsets for Huawei:')
print(huawei_top_5)
# Out:
# Top 5 Handsets for Apple:
# Handset Type
# Apple iPhone 6S (A1688)    9419
# Apple iPhone 6 (A1586)     9023
# Apple iPhone 7 (A1778)     6326
# Apple iPhone Se (A1723)    5187
# Apple iPhone 8 (A1905)     4993
# Name: count, dtype: int64
# Top 5 Handsets for Samsung:
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4520
# Samsung Galaxy A5 Sm-A520F      3724
# Samsung Galaxy J5 (Sm-J530)     3696
# Samsung Galaxy J3 (Sm-J330)     3484
# Samsung Galaxy S7 (Sm-G930X)    3199
# Name: count, dtype: int64
# Top 5 Handsets for Huawei:
# Handset Type
# Huawei B528S-23A                  19752
# Huawei E5180                       2079
# Huawei P20 Lite Huawei Nova 3E     2021
# Huawei P20                         1480
# Huawei Y6 2018                      997
# Name: count, dtype: int64

# %% [markdown]
# - Top 10 Handsets Used by Customers:
# Huawei B528S-23A
# Apple iPhone 6S (A1688)
# Apple iPhone 6 (A1586)
# undefined
# Apple iPhone 7 (A1778)
# Apple iPhone Se (A1723)
# Apple iPhone 8 (A1905)
# Apple iPhone Xr (A2105)
# Samsung Galaxy S8 (Sm-G950F)
# Apple iPhone X (A1901)
#
# - Top 3 Handset Manufacturers:
# Apple
# Samsung
# Huawei
#
#
# - Top 5 Handsets for Apple:
# Apple iPhone 6S (A1688)
# Apple iPhone 6 (A1586)
# Apple iPhone 7 (A1778)
# Apple iPhone Se (A1723)
# Apple iPhone 8 (A1905)
#
# - Top 5 Handsets for Samsung:
# Samsung Galaxy S8 (Sm-G950F)
# Samsung Galaxy A5 Sm-A520F
# Samsung Galaxy J5 (Sm-J530)
# Samsung Galaxy J3 (Sm-J330)
# Samsung Galaxy S7 (Sm-G930X)
#
# - Top 5 Handsets for Huawei:
# Huawei B528S-23A
# Huawei E5180
# Huawei P20 Lite Huawei Nova 3E
# Huawei P20
# Huawei Y6 2018

# %%
#4
# Grouping the data by user and counting the number of xDR sessions per user
df_xdr_sessions = df.groupby('MSISDN/Number')['Bearer Id'].count().reset_index(name='number_of_xDR_sessions')
print('Number of xDR Sessions per User:')
print(df_xdr_sessions.head())
# Out:
# Number of xDR Sessions per User:
#    MSISDN/Number  number_of_xDR_sessions
# 0   3.360100e+10                       1
# 1   3.360100e+10                       1
# 2   3.360100e+10                       1
# 3   3.360101e+10                       1
# 4   3.360101e+10                       2

# %%
#5
# Calculating the total session duration per user
df_total_session_duration = df.groupby('MSISDN/Number')['Dur. (ms)'].sum().reset_index(name='total_session_duration')
print('Total Session Duration per User:')
print(df_total_session_duration.head())
# Out:
# Total Session Duration per User:
#    MSISDN/Number  total_session_duration
# 0   3.360100e+10                116720.0
# 1   3.360100e+10                181230.0
# 2   3.360100e+10                134969.0
# 3   3.360101e+10                 49878.0
# 4   3.360101e+10                 37104.0

# %% [markdown]
# - User 3.360100e+10 had the highest session duration

# %%
#6
# Calculating the total download (DL) and upload (UL) data per user
df_total_dl_ul = df.groupby('MSISDN/Number').agg(
    total_download_data=('Total DL (Bytes)', 'sum'),
    total_upload_data=('Total UL (Bytes)', 'sum')
).reset_index()
print('Total Download and Upload Data per User:')
print(df_total_dl_ul.head())
# Out:
# Total Download and Upload Data per User:
#    MSISDN/Number  total_download_data  total_upload_data
# 0   3.360100e+10         8.426375e+08         36053108.0
# 1   3.360100e+10         1.207552e+08         36104459.0
# 2   3.360100e+10         5.566597e+08         39306820.0
# 3   3.360101e+10         4.019932e+08         20327526.0
# 4   3.360101e+10         1.363130e+09         94280527.0

# %%
# Sort the DataFrame by 'total_traffic' in descending order to get the top users
df_top_dl_ul = df_total_dl_ul.sort_values(by='total_download_data', ascending=False).head()
df_top_dl_ul
# Out:
#         MSISDN/Number  total_download_data  total_upload_data
# 106853   4.188282e+10         4.873783e+11       4.436642e+10
# 6437     3.361489e+10         8.156743e+09       6.894830e+08
# 92923    3.376054e+10         7.811295e+09       7.034786e+08
# 13180    3.362578e+10         7.770043e+09       7.295774e+08
# 76363    3.367588e+10         7.309542e+09       5.815688e+08

# %% [markdown]
# - The top 5 users as per dl and ul are: **4.188282e+10**, **3.361489e+10**, **3.376054e+10**, **3.362578e+10**, **3.367588e+10**

# %%
#7 the total data volume (in Bytes) during this session for each application
# Correcting the column names and recalculating the total download and upload data for each user
df['Total_DL_UL'] = df['Total DL (Bytes)'] + df['Total UL (Bytes)']

# Bivariate analysis between each application's data usage and the total DL+UL data
application_columns = ['Social Media DL (Bytes)', 'Social Media UL (Bytes)', 'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)', 'Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)']

# Calculating total data usage for each application by summing download and upload
df['total_social_media'] = df['Social Media DL (Bytes)'] + df['Social Media UL (Bytes)']
df['total_google'] = df['Google DL (Bytes)'] + df['Google UL (Bytes)']
df['total_email'] = df['Email DL (Bytes)'] + df['Email UL (Bytes)']
df['total_youtube'] = df['Youtube DL (Bytes)'] + df['Youtube UL (Bytes)']
df['total_netflix'] = df['Netflix DL (Bytes)'] + df['Netflix UL (Bytes)']
df['total_gaming'] = df['Gaming DL (Bytes)'] + df['Gaming UL (Bytes)']
df['total_other'] = df['Other DL (Bytes)'] + df['Other UL (Bytes)']

# Correlation matrix for application data usage and total DL+UL data
correlation_matrix = df[['total_social_media', 'total_google', 'total_email', 'total_youtube', 'total_netflix', 'total_gaming', 'total_other', 'Total_DL_UL']].corr()

# %%
# 7
# Now aggregating the total data per user
df_total_app_data = df.groupby('MSISDN/Number').agg(
    total_social_media_data=('total_social_media', 'sum'),
    total_google_data=('total_google', 'sum'),
    total_email_data=('total_email', 'sum'),
    total_youtube_data=('total_youtube', 'sum'),
    total_netflix_data=('total_netflix', 'sum'),
    total_gaming_data=('total_gaming', 'sum'),
    total_other_data=('total_other', 'sum')
).reset_index()
print('Total Data Volume Consumption per Application per User:')
print(df_total_app_data.head())
# Out:
# Total Data Volume Consumption per Application per User:
#    MSISDN/Number  total_social_media_data  total_google_data  \
# 0   3.360100e+10                2232135.0          4389005.0
# 1   3.360100e+10                2660565.0          5334863.0
# 2   3.360100e+10                3195623.0          3443126.0
# 3   3.360101e+10                 280294.0          9678493.0
# 4   3.360101e+10                2912542.0         18499616.0
#
#    total_email_data  total_youtube_data  total_netflix_data  \
# 0         1331362.0          21624548.0          27180981.0
# 1         3307781.0          12432223.0          11221763.0
# 2         3205380.0          21333570.0          19353900.0
# 3         2284670.0           6977321.0           1942092.0
# 4         3305469.0          41533002.0          49201724.0
#
#    total_gaming_data  total_other_data
# 0       8.124587e+08       386570872.0
# 1       1.197501e+08       281710071.0
# 2       5.388277e+08       501693672.0
# ...

# %%
# Sort the DataFrame by 'total_traffic' in descending order to get the top users
top_df_total_app_data= df_total_app_data.sort_values(by='total_social_media_data', ascending=False).head()
top_df_total_app_data
# Out:
#         MSISDN/Number  total_social_media_data  total_google_data  \
# 106853   4.188282e+10             1.973817e+09       8.248577e+09
# 13526    3.362632e+10             4.337478e+07       1.521919e+08
# 92923    3.376054e+10             3.978319e+07       1.232231e+08
# 37052    3.365973e+10             3.541236e+07       1.165163e+08
# 6437     3.361489e+10             2.829454e+07       1.279738e+08
#
#         total_email_data  total_youtube_data  total_netflix_data  \
# 106853      2.399880e+09        2.434073e+10        2.425357e+10
# 13526       4.241878e+07        3.744830e+08        3.287257e+08
# 92923       3.369377e+07        3.962892e+08        3.346433e+08
# 37052       3.599979e+07        2.579911e+08        3.995191e+08
# 6437        4.078863e+07        3.943702e+08        3.614010e+08
#
#         total_gaming_data  total_other_data
# 106853       4.614780e+11      4.509784e+11
# 13526        6.887572e+09      8.167878e+09
# ...

# %% [markdown]
# - Top 5 users of social media data are: **4.188282e+10, 3.362632e+10, 3.376054e+10, 3.365973e+10, 3.361489e+10**

# %%
#8
# Filtering out non-numeric columns and recalculating dispersion parameters
numeric_cols = df.select_dtypes(include=['number'])
dispersion_params_numeric = numeric_cols.agg(['var', 'std', 'min', 'max'])
dispersion_params_numeric['range'] = dispersion_params_numeric.loc['max'] - dispersion_params_numeric.loc['min']
dispersion_params_numeric['IQR'] = numeric_cols.quantile(0.75) - numeric_cols.quantile(0.25)
print('Dispersion Parameters for Numeric Variables:')
dispersion_params_numeric
# Out:
# Dispersion Parameters for Numeric Variables:
#          Start ms        End ms     Dur. (ms)  Avg RTT DL (ms)  \
# var  83296.235554  82999.704445  6.567052e+09     312864.16620
# std    288.610872    288.096693  8.103735e+04        559.34262
# min      0.000000      0.000000  7.142000e+03          0.00000
# max    999.000000    999.000000  1.859336e+06      96923.00000
#
#      Avg RTT UL (ms)  Avg Bearer TP DL (kbps)  Avg Bearer TP UL (kbps)  \
# var      5856.830663             5.746471e+08             2.139377e+07
# std        76.529933             2.397180e+04             4.625340e+03
# min         0.000000             0.000000e+00             0.000000e+00
# max      7120.000000             3.781600e+05             5.861300e+04
#
#      TCP DL Retrans. Vol (Bytes)  TCP UL Retrans. Vol (Bytes)  \
# var                 1.374418e+16                 2.488873e+14
# std                 1.172356e+08                 1.577616e+07
# ...

# %% [markdown]
# - These metrics are crucial for understanding the variability and distribution of the data, which can help in identifying outliers, understanding data spread, and making further decisions about data modeling and analysis.

# %%
# 9
# correlation map
plt.figure(figsize=(15, 5))
sns.heatmap(correlation_matrix, annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %% [markdown]
# - Gaming: Shows a very high correlation (approximately 0.998) with the total data usage (DL+UL). This suggests that gaming applications are a significant contributor to the total data usage on the network.
# - Youtube and Netflix: Both have moderate correlations (around 0.035) with total data usage. This indicates that while they contribute to data usage, their impact is less compared to gaming.
# - Social Media, Google, and Email: These applications show very low correlations (ranging from -0.002 to 0.005) with total data usage, implying that their data demands are relatively minor in the context of total data usage.

# %%
# 10  segment the users into top five decile classes based on the total duration for all sessions and compute the total data (DL+UL) per decile class. 
# Calculating the total session duration for each user
df['Total_Session_Duration'] = df.groupby('MSISDN/Number')['Dur. (ms)'].transform('sum')

# Segmenting the users into top five decile classes based on total session duration
df['Decile_Class'] = pd.qcut(df['Total_Session_Duration'], 10, labels=False) + 1  # +1 to make deciles 1 to 10

# Filtering for top five deciles (6 to 10)
top_deciles = df[df['Decile_Class'] >= 6]

# Calculating the total data (DL+UL) for each decile class
total_data_per_decile = top_deciles.groupby('Decile_Class')['Total_DL_UL'].sum()

# Displaying the results
print('Total Data (DL+UL) per Decile Class (Top Five Deciles):')
print(total_data_per_decile)
# Out:
# Total Data (DL+UL) per Decile Class (Top Five Deciles):
# Decile_Class
# 6     8.095113e+12
# 7     6.778635e+12
# 8     7.446793e+12
# 9     7.411643e+12
# 10    7.414538e+12
# Name: Total_DL_UL, dtype: float64

# %% [markdown]
# ##### Task 3

# %%
# Compute the Session Frequency
session_frequency = df['MSISDN/Number'].value_counts()

# Compute the Duration of the User's Sessions
session_duration = df.groupby('MSISDN/Number')['Total_Session_Duration'].sum()

# Compute the Total Traffic (download and upload)
df['total_traffic'] = df['Total_DL_UL']
total_traffic = df.groupby('MSISDN/Number')['total_traffic'].sum()

# Displaying the computed metrics
print('Session Frequency:')
print(session_frequency.head())
print('\
Session Duration:')
print(session_duration.head())
print('\
Total Traffic:')
print(total_traffic.head())
# Out:
# Session Frequency:
# MSISDN/Number
# 41882819545.027359    1066
# 33626320676.0           18
# 33625779332.0           17
# 33614892860.0           17
# 33659725664.0           16
# Name: count, dtype: int64
# Session Duration:
# MSISDN/Number
# 3.360100e+10    116720.0
# 3.360100e+10    181230.0
# 3.360100e+10    134969.0
# 3.360101e+10     49878.0
# 3.360101e+10     74208.0
# Name: Total_Session_Duration, dtype: float64
# Total Traffic:
# MSISDN/Number
# 3.360100e+10    8.786906e+08
# 3.360100e+10    1.568596e+08
# 3.360100e+10    5.959665e+08
# 3.360101e+10    4.223207e+08
# 3.360101e+10    1.457411e+09
# Name: total_traffic, dtype: float64

# %%
# Aggregate the above metrics per customer id (MSISDN) and report the top 10 customers per engagement metric 
# Aggregating the engagement metrics per customer ID (MSISDN)
engagement_metrics = df.groupby('MSISDN/Number').agg({
    'Dur. (ms)': 'sum',
    'Total UL (Bytes)': 'sum',
    'Total DL (Bytes)': 'sum'
})
engagement_metrics['Total Traffic (Bytes)'] = engagement_metrics['Total UL (Bytes)'] + engagement_metrics['Total DL (Bytes)']

# Reporting the top 10 customers per engagement metric
top_10_duration = engagement_metrics.nlargest(10, 'Dur. (ms)')
top_10_traffic = engagement_metrics.nlargest(10, 'Total Traffic (Bytes)')

print('Top 10 Customers by Session Duration:')
print(top_10_duration)
print('\
Top 10 Customers by Total Traffic:')
print(top_10_traffic)
# Out:
# Top 10 Customers by Session Duration:
#                   Dur. (ms)  Total UL (Bytes)  Total DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10   7.255100e+07      4.436642e+10      4.873783e+11
# 3.362578e+10   1.855375e+07      7.295774e+08      7.770043e+09
# 3.361489e+10   9.966898e+06      6.894830e+08      8.156743e+09
# 3.376054e+10   9.279434e+06      7.034786e+08      7.811295e+09
# 3.362632e+10   8.791927e+06      6.696507e+08      7.301517e+09
# 3.366716e+10   8.744914e+06      5.663264e+08      5.052068e+09
# 3.366284e+10   6.614270e+06      4.064244e+08      3.593674e+09
# 3.366469e+10   6.288730e+06      4.021808e+08      5.279827e+09
# 3.360313e+10   6.287761e+06      4.355876e+08      4.540607e+09
# 3.366746e+10   5.649882e+06      2.662226e+08      2.334299e+09
#
#                Total Traffic (Bytes)
# MSISDN/Number
# 4.188282e+10            5.317447e+11
# 3.362578e+10            8.499621e+09
# 3.361489e+10            8.846226e+09
# 3.376054e+10            8.514774e+09
# ...

# %%
engagement_metrics
# Out:
#                   Dur. (ms)  Total UL (Bytes)  Total DL (Bytes)  \
# MSISDN/Number
# 3.360100e+10   1.167200e+05      3.605311e+07      8.426375e+08
# 3.360100e+10   1.812300e+05      3.610446e+07      1.207552e+08
# 3.360100e+10   1.349690e+05      3.930682e+07      5.566597e+08
# 3.360101e+10   4.987800e+04      2.032753e+07      4.019932e+08
# 3.360101e+10   3.710400e+04      9.428053e+07      1.363130e+09
# ...                     ...               ...               ...
# 3.379000e+10   1.409880e+05      3.573224e+07      4.445751e+08
# 4.188282e+10   7.255100e+07      4.436642e+10      4.873783e+11
# 3.197021e+12   8.773850e+05      3.729592e+07      1.948281e+08
# 3.370000e+14   2.530300e+05      5.665284e+07      5.396350e+08
# 8.823971e+14   8.698440e+05      6.045605e+07      7.869760e+07
#
#                Total Traffic (Bytes)
# MSISDN/Number
# 3.360100e+10            8.786906e+08
# 3.360100e+10            1.568596e+08
# 3.360100e+10            5.959665e+08
# ...

# %% [markdown]
# - Users **4.188282e+10, 3.362578e+10, 3.361489e+10** have the longest XDR

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Normalizing the engagement metrics
scaler = StandardScaler()
engagement_metrics_scaled = scaler.fit_transform(engagement_metrics[['Dur. (ms)', 'Total Traffic (Bytes)']])

# Running K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=0)
clusters = kmeans.fit_predict(engagement_metrics_scaled)
engagement_metrics['Cluster'] = clusters

# Compute the minimum, maximum, average & total non-normalized metrics for each cluster
cluster_summary = engagement_metrics.groupby('Cluster').agg({
    'Dur. (ms)': ['min', 'max', 'mean', 'sum'],
    'Total Traffic (Bytes)': ['min', 'max', 'mean', 'sum']
})

print(cluster_summary)
# Out:
#             Dur. (ms)                                            \
#                   min           max          mean           sum
# Cluster
# 0        7.142000e+03  3.997920e+05  1.150797e+05  1.138852e+10
# 1        7.255100e+07  7.255100e+07  7.255100e+07  7.255100e+07
# 2        1.706800e+05  1.855375e+07  5.358902e+05  4.230318e+09
#
#         Total Traffic (Bytes)
#                           min           max          mean           sum
# Cluster
# 0                3.324901e+07  3.271920e+09  6.148726e+08  6.084902e+13
# 1                5.317447e+11  5.317447e+11  5.317447e+11  5.317447e+11
# 2                5.212838e+07  8.846226e+09  1.644848e+09  1.298443e+13

# %%
# Visualizing the cluster summary for interpretation
import matplotlib.pyplot as plt

# Setting up the figure
plt.figure(figsize=(14, 7))

# Plotting Duration metrics
plt.subplot(1, 2, 1)
plt.bar(['Cluster 0', 'Cluster 1', 'Cluster 2'], cluster_summary['Dur. (ms)']['mean'], color=['red', 'green', 'blue'])
plt.title('Average Session Duration per Cluster')
plt.ylabel('Duration (ms)')

# Plotting Traffic metrics
plt.subplot(1, 2, 2)
plt.bar(['Cluster 0', 'Cluster 1', 'Cluster 2'], cluster_summary['Total Traffic (Bytes)']['mean'], color=['red', 'green', 'blue'])
plt.title('Average Total Traffic per Cluster')
plt.ylabel('Total Traffic (Bytes)')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Cluster 0: Represents users with low to moderate session durations and traffic.
# - Cluster 1: Represents users with moderate to high session durations and higher traffic.
# - Cluster 2: Represents users with the highest session durations and traffic, likely power users.

# %%
# Aggregating user total traffic per application
total_traffic_per_app = df.groupby('MSISDN/Number')[['Social Media DL (Bytes)', 'Social Media UL (Bytes)', 'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)', 'Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)']].sum()

# Calculating total traffic for each application
total_traffic_per_app['Social Media'] = total_traffic_per_app['Social Media DL (Bytes)'] + total_traffic_per_app['Social Media UL (Bytes)']
total_traffic_per_app['Google'] = total_traffic_per_app['Google DL (Bytes)'] + total_traffic_per_app['Google UL (Bytes)']
total_traffic_per_app['Email'] = total_traffic_per_app['Email DL (Bytes)'] + total_traffic_per_app['Email UL (Bytes)']
total_traffic_per_app['Youtube'] = total_traffic_per_app['Youtube DL (Bytes)'] + total_traffic_per_app['Youtube UL (Bytes)']
total_traffic_per_app['Netflix'] = total_traffic_per_app['Netflix DL (Bytes)'] + total_traffic_per_app['Netflix UL (Bytes)']
total_traffic_per_app['Gaming'] = total_traffic_per_app['Gaming DL (Bytes)'] + total_traffic_per_app['Gaming UL (Bytes)']
total_traffic_per_app['Other'] = total_traffic_per_app['Other DL (Bytes)'] + total_traffic_per_app['Other UL (Bytes)']

# Deriving the top 10 most engaged users per application
top_10_social_media = total_traffic_per_app.nlargest(10, 'Social Media')
top_10_google = total_traffic_per_app.nlargest(10, 'Google')
top_10_email = total_traffic_per_app.nlargest(10, 'Email')
top_10_youtube = total_traffic_per_app.nlargest(10, 'Youtube')
top_10_netflix = total_traffic_per_app.nlargest(10, 'Netflix')
top_10_gaming = total_traffic_per_app.nlargest(10, 'Gaming')
top_10_other = total_traffic_per_app.nlargest(10, 'Other')

print('Top 10 Most Engaged Users per Application:')
print('Social Media:')
print(top_10_social_media)
print('\
Google:')
print(top_10_google)
print('\
Email:')
print(top_10_email)
print('\
Youtube:')
print(top_10_youtube)
print('\
Netflix:')
print(top_10_netflix)
print('\
Gaming:')
print(top_10_gaming)
print('\
Other:')
print(top_10_other)
# Out:
# Top 10 Most Engaged Users per Application:
# Social Media:
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10              1.937715e+09             3.610230e+07
# 3.362632e+10              4.274384e+07             6.309420e+05
# 3.376054e+10              3.929765e+07             4.855430e+05
# 3.365973e+10              3.490044e+07             5.119140e+05
# 3.361489e+10              2.774974e+07             5.448000e+05
# 3.362578e+10              2.656412e+07             5.713790e+05
# 3.366716e+10              2.375375e+07             4.940970e+05
# 3.378632e+10              2.356866e+07             4.062640e+05
# 3.366907e+10              2.347705e+07             3.237870e+05
# 3.360313e+10              2.277668e+07             3.011460e+05
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10        6.007942e+09       2.240634e+09      1.904048e+09
# ...

# %%
# Plotting the top 3 most used applications
# Summing up the total traffic for each application
total_traffic = total_traffic_per_app[['Social Media', 'Google', 'Email', 'Youtube', 'Netflix', 'Gaming', 'Other']].sum()

# Sorting to find the top 3
top_5_apps = total_traffic.sort_values(ascending=False).head(5)

# Plotting
plt.figure(figsize=(10, 6), facecolor='white')
plt.bar(top_5_apps.index, top_5_apps.values, color=['red', 'green', 'blue'])
plt.title('Top 5 Most Used Applications by Total Traffic')
plt.xlabel('Application')
plt.ylabel('Total Traffic (Bytes)')
plt.show()

# %% [markdown]
# - The top 5 Most Used Applications by Total Traffic are **Gaming, Other, Youtube, Netflix, Google**

# %%
# Using the elbow method to find the optimal k
inertia = []
k_range = range(1, 11)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(engagement_metrics_scaled)
    inertia.append(kmeans.inertia_)

# Plotting the elbow curve
plt.figure(figsize=(8, 4))
plt.plot(k_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# Selecting the optimal k (example, usually where the elbow is)
optimal_k = 2

# Clustering with the optimal k
kmeans_optimal = KMeans(n_clusters=optimal_k, random_state=0)
clusters = kmeans_optimal.fit_predict(engagement_metrics_scaled)
engagement_metrics['Cluster'] = clusters

# Displaying the first few rows of the DataFrame with clusters
print(engagement_metrics.head())
# Out:
#                Dur. (ms)  Total UL (Bytes)  Total DL (Bytes)  \
# MSISDN/Number
# 3.360100e+10    116720.0        36053108.0      8.426375e+08
# 3.360100e+10    181230.0        36104459.0      1.207552e+08
# 3.360100e+10    134969.0        39306820.0      5.566597e+08
# 3.360101e+10     49878.0        20327526.0      4.019932e+08
# 3.360101e+10     37104.0        94280527.0      1.363130e+09
#
#                Total Traffic (Bytes)  Cluster
# MSISDN/Number
# 3.360100e+10            8.786906e+08        0
# 3.360100e+10            1.568596e+08        0
# 3.360100e+10            5.959665e+08        0
# 3.360101e+10            4.223207e+08        0
# 3.360101e+10            1.457411e+09        0

# %% [markdown]
# - After applying the k-means clustering algorithm with the determined optimal k, users were grouped into different clusters based on their engagement metrics. Each cluster represents a group of users with similar levels of engagement, which can be analyzed to understand different user behaviors and preferences.

# %% [markdown]
# ##### Task 4

# %%
# Calculate the average TCP retransmission, average RTT, and average throughput per customer
df['Average TCP Retransmission'] = (df['TCP DL Retrans. Vol (Bytes)'] + df['TCP UL Retrans. Vol (Bytes)']) / 2
df['Average RTT'] = (df['Avg RTT DL (ms)'] + df['Avg RTT UL (ms)']) / 2
df['Average Throughput'] = (df['Avg Bearer TP DL (kbps)'] + df['Avg Bearer TP UL (kbps)']) / 2

# Group by MSISDN/Number (customer) and calculate the mean for the averages and get the most common handset type
customer_agg = df.groupby('MSISDN/Number').agg({
    'Average TCP Retransmission': 'mean',
    'Average RTT': 'mean',
    'Handset Type': lambda x: x.mode()[0],  # Most common handset type
    'Average Throughput': 'mean'
}).reset_index()

customer_agg.head()
# Out:
#    MSISDN/Number  Average TCP Retransmission  Average RTT  \
# 0   3.360100e+10                1.078479e+07    23.000000
# 1   3.360100e+10                1.078479e+07    15.500000
# 2   3.360100e+10                1.078479e+07    63.729294
# 3   3.360101e+10                3.803623e+05    42.000000
# 4   3.360101e+10                7.735101e+06    29.750000
#
#                      Handset Type  Average Throughput
# 0  Huawei P20 Lite Huawei Nova 3E                38.0
# 1          Apple iPhone 7 (A1778)                49.5
# 2                       undefined                48.5
# 3         Apple iPhone 5S (A1457)               124.0
# 4         Apple iPhone Se (A1723)             14211.0

# %%
# Compute the top, bottom, and most frequent TCP, RTT, and Throughput values
def top_bottom_frequent(series):
    top_values = series.nlargest(10)
    bottom_values = series.nsmallest(10)
    frequent_values = series.value_counts().nlargest(10)
    return top_values, bottom_values, frequent_values

# TCP values
top_tcp, bottom_tcp, frequent_tcp = top_bottom_frequent(df['Average TCP Retransmission'])
# RTT values
top_rtt, bottom_rtt, frequent_rtt = top_bottom_frequent(df['Average RTT'])
# Throughput values
top_throughput, bottom_throughput, frequent_throughput = top_bottom_frequent(df['Average Throughput'])

print('Top TCP Values:\
', top_tcp)
print('Bottom TCP Values:\
', bottom_tcp)
print('Most Frequent TCP Values:\
', frequent_tcp)
print('Top RTT Values:\
', top_rtt)
print('Bottom RTT Values:\
', bottom_rtt)
print('Most Frequent RTT Values:\
', frequent_rtt)
print('Top Throughput Values:\
', top_throughput)
print('Bottom Throughput Values:\
', bottom_throughput)
print('Most Frequent Throughput Values:\
', frequent_throughput)
# Out:
# Top TCP Values: 34645     2.172058e+09
# 140813    2.150739e+09
# 77979     2.147216e+09
# 135678    2.145732e+09
# 3782      2.144060e+09
# 119684    2.137746e+09
# 39637     2.134324e+09
# 59016     2.130808e+09
# 76990     2.130087e+09
# 41209     2.127330e+09
# Name: Average TCP Retransmission, dtype: float64
# Bottom TCP Values: 143594    43.0
# 111113    48.5
# 18432     53.0
# 13157     54.0
# 97070     56.5
# 8816      64.0
# 99959     64.5
# 83227     67.0
# 95966     67.0
# 12866     71.5
# Name: Average TCP Retransmission, dtype: float64
# Most Frequent TCP Values: Average TCP Retransmission
# 1.078479e+07    85265
# 1.040560e+07      650
# 3.804943e+05      249
# 1.040562e+07      248
# 3.798483e+05      136
# 3.798753e+05      132
# 1.040562e+07      132
# 3.811593e+05      121
# 3.804883e+05      106
# 1.040629e+07       99
# Name: count, dtype: int64
# Top RTT Values: 30166     48462.0
# 29927     32320.5
# 17910     27906.0
# 5989      27424.0
# 22851     13639.0
# ...

# %%
# Compute the distribution of the average throughput per handset type
df_throughput_handset = df.groupby('Handset Type')['Average Throughput'].mean().sort_values(ascending=False)
# Compute the average TCP retransmission per handset type
df_tcp_handset = df.groupby('Handset Type')['Average TCP Retransmission'].mean().sort_values(ascending=False)

# Set the aesthetic style of the plots
sns.set(style='whitegrid')

# Create a larger figure for better readability
plt.figure(figsize=(14, 8))

# Plot the average throughput per handset type using seaborn for better visualization
sns.barplot(x=df_throughput_handset.head(20).index, y=df_throughput_handset.head(20).values, palette='Blues_d')
plt.title('Top 20 Handset Types by Average Throughput', fontsize=16)
plt.xlabel('Handset Type', fontsize=14)
plt.ylabel('Average Throughput (kbps)', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# Create another figure for TCP retransmission
plt.figure(figsize=(14, 8))

# Plot the average TCP retransmission per handset type using seaborn
sns.barplot(x=df_tcp_handset.head(20).index, y=df_tcp_handset.head(20).values, palette='Oranges_d')
plt.title('Top 20 Handset Types by Average TCP Retransmission', fontsize=16)
plt.xlabel('Handset Type', fontsize=14)
plt.ylabel('Average TCP Retransmission (Bytes)', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Throughput: Handsets with higher average throughput are likely newer or more advanced models that support higher data rates, which is beneficial for streaming, gaming, and high-speed internet activities.
# - TCP Retransmission: Handsets with higher average TCP retransmissions might be experiencing more network issues or may not be as well optimized for the network they are used on. This could affect user experience negatively, leading to slower browsing and data transfer rates.

# %% [markdown]
# ## Recommendations
#
# 1. Invest in Network Infrastructure Improvements:
#
#     - Enhance Coverage and Capacity: For clusters experiencing high TCP retransmissions and RTT, investing in network infrastructure to enhance signal coverage and data capacity could significantly improve service quality.
#
#     - Advanced Technologies: Consider deploying advanced technologies such as 5G or enhanced 4G LTE to improve throughput and reduce latency, particularly in clusters with high data usage.
#
# 2. Targeted Marketing and Service Offerings:
#
#     - Customized Plans: Develop tailored data plans or service packages for each user cluster. For instance, users in the high throughput cluster might benefit from premium service offerings, while those in the high retransmission cluster might appreciate plans offering better stability.
#
#     - Promotional Campaigns: Run promotional campaigns that highlight improvements or special features that address the specific needs of each cluster.
#
# 3. Customer Retention and Satisfaction:
#
#     - Proactive Customer Support: Implement proactive support measures for clusters experiencing poor network performance. This could include automatic notifications and compensations for service disruptions.
#
#     - Feedback Mechanism: Establish a robust feedback mechanism to gather real-time data from users about their service experience, enabling continuous improvement.
